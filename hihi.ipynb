# %% [markdown]
# <a href="https://colab.research.google.com/github/PGHungg/Tet/blob/main/hihi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Copy Folder Google Drive to Google Drive - 1TouchPro

# %%
#@title Input
from ipywidgets import widgets

dest_text = widgets.Text(description="Your drive", placeholder='https://drive.google.com/drive/folders/1_OpXBCk8xqypoTxu8OTDDHShsY0KhBc6?usp=sharing', value='https://drive.google.com/drive/folders/1_OpXBCk8xqypoTxu8OTDDHShsY0KhBc6?usp=sharing')
source_text = widgets.Text(description="Shared drive", placeholder='https://drive.google.com/drive/folders/1XoAUOmxo16bhp6NOKMitPyAiUpRaxhc-?usp=drive_link', value='https://drive.google.com/drive/folders/1XoAUOmxo16bhp6NOKMitPyAiUpRaxhc-?usp=drive_link')
from_page_text = widgets.Text(description="Từ trang", value="0")
to_page_text = widgets.Text(description="Đến trang", value="1000")
max_download_size_text = widgets.Text(description="Tổng dung lượng tối đa(GB)", value="10")
exclude_str_text = widgets.Text(description="Bỏ file, folder có chứa nội dung", value="")

display(dest_text)
display(source_text)
display(from_page_text)
display(to_page_text)
display(max_download_size_text)
display(exclude_str_text)
# Out:
# Text(value='https://drive.google.com/drive/folders/1_OpXBCk8xqypoTxu8OTDDHShsY0KhBc6?usp=sharing', description…
# Text(value='https://drive.google.com/drive/folders/1XoAUOmxo16bhp6NOKMitPyAiUpRaxhc-?usp=drive_link', descript…
# Text(value='0', description='Từ trang')
# Text(value='1000', description='Đến trang')
# Text(value='10', description='Tổng dung lượng tối đa(GB)')
# Text(value='', description='Bỏ file, folder có chứa nội dung')

# %%
#@title Run
import os
import time
import re
import sys
from googleapiclient.discovery import build
from google.colab import auth
from google.colab import drive

class DownloadFromDrive:
    def __init__(self):
        self._total_size = 0
        self._limit_size = 0
        self.excluded_strings = []

    def get_user_credential(self):
        auth.authenticate_user()
        drive_service = build('drive', 'v3')
        return drive_service

    def get_childs_from_folder(self, drive_service, folder_id, from_page, to_page):
        files = []
        page_token = None
        query = f"'{folder_id}' in parents and trashed = false"
        if self.excluded_strings and len(self.excluded_strings) > 0:
            not_contains_query = " and ".join([f"not name contains '{ext}'" for ext in self.excluded_strings])
            query += f" and ({not_contains_query})"

        pages = 0
        while True:
            try:
                pages += 1
                response = drive_service.files().list(q=query,
                                        orderBy='name, createdTime',
                                        fields='files(id, name, mimeType, size), nextPageToken',
                                        pageToken=page_token,
                                        supportsAllDrives=True,
                                        includeItemsFromAllDrives=True).execute()

                if (from_page < pages <= to_page) or to_page == 0:
                    files.extend(response.get('files', []))

                page_token = response.get('nextPageToken', None)
                if page_token is None or  (pages >= to_page > 0):
                    break
            except Exception as e:
                print(f"An error occurred: {str(e)}")
                page_token = None

        print(f"Total files: {len(files)}")
        return files

    def copy_file(self, drive_service, dest_folder_id, source_file):
        if source_file['mimeType'] != 'application/vnd.google-apps.folder':
            body_file_inf = {'parents': [dest_folder_id]}

            if not self.check_if_exists(drive_service, dest_folder_id, source_file['name']):
                try:
                    start_time = time.time()
                    request_copy = drive_service.files().copy(body=body_file_inf, fileId=source_file['id'],
                                                              supportsAllDrives=True).execute()
                    end_time = time.time()

                    fileSize = int(source_file.get('size', 0))
                    size_mb = fileSize / (1024 * 1024)
                    self._total_size += size_mb
                    speed_mb = size_mb / (end_time - start_time)
                    print(f"[{source_file['name']}] copied. Size {size_mb:0.2f} MB. Speed {speed_mb:0.2f} MB/s")


                    if self._total_size >= (self._limit_size * 1024):
                        self.on_total_size_exceeded(f"Total size exceeds {self._limit_size} GB. Ending the program.")
                except Exception as e:
                    print("An error occurred: ", e)
            else:
                print(f"[{source_file['name']}] exists.")
        else:

            source_files = self.get_childs_from_folder(drive_service, source_file['id'], 0, 0)
            if source_files and len(source_files) > 0:
                print(f"Copy at Folder {source_file['name']} Starting")
                sub_folder_id = self.create_folder(drive_service, dest_folder_id, source_file['name'])
                self.copy_multiple_files(drive_service, sub_folder_id, source_files)
                print(f"Copy at Folder {source_file['name']} Ending")


    def create_folder(self, drive_service, dest_folder_id, sub_folder_name):
        sub_folder_inf = {'name': sub_folder_name, 'mimeType': 'application/vnd.google-apps.folder', 'parents': [dest_folder_id]}

        exist_folder_id = self.check_if_exists(drive_service, dest_folder_id, sub_folder_name)
        if not exist_folder_id:
            try:
                folder = drive_service.files().create(body=sub_folder_inf, fields='id').execute()
                return folder['id']
            except Exception as e:
                print("An error occurred: ", e)
        return exist_folder_id


    def check_if_exists(self, drive_service, dest_folder_id, name):
        try:
            processed_name = name.replace("'", "\\'")

            results = drive_service.files().list(q=f"'{dest_folder_id}' in parents and name contains '{processed_name}' and trashed=false",
                                                fields='files(id)').execute()

            if 'files' in results and len(results['files']) > 0:
                return results['files'][0]['id']
        except Exception as e:
            print("An error occurred: ", e)

        return ""


    def copy_multiple_files(self, drive_service, dest_folder_id, source_files):
        for source_file in source_files:
            self.copy_file(drive_service, dest_folder_id, source_file)

    def extract_folder_id_from_url(self, url):
        pattern = r'[-\w]{25,}'
        match = re.search(pattern, url)
        if match:
            return match.group(0)
        else:
            return None

    def on_total_size_exceeded(self, message):
        print(message)
        sys.exit()

    def copy_drive_to_drive(self, destDriveLink, sourceDriveLink, from_page, to_page):
        service = self.get_user_credential()

        start_time = time.time()
        dest_folder_id = self.extract_folder_id_from_url(destDriveLink)
        source_folder_id = self.extract_folder_id_from_url(sourceDriveLink)

        if not source_folder_id:
            print("Error: Could not extract source folder ID from the provided link.")
            return

        source_folder = service.files().get(fileId=source_folder_id, supportsAllDrives=True).execute()
        new_dest_folder_id = self.create_folder(service, dest_folder_id, source_folder['name'])

        source_files = self.get_childs_from_folder(service, source_folder_id, from_page, to_page)
        self.copy_multiple_files(service, new_dest_folder_id, source_files)
        end_time = time.time()

        size_gb = self._total_size / 1024
        speed_mb = self._total_size / (end_time - start_time)

        print(f"Done. Total Size {size_gb:0.2f} GB. Total Time {int(end_time - start_time)} s. SpeedMB {speed_mb:0.2f} MB/s")


# Main
destDriveLink = dest_text.value
sourceDriveLink = source_text.value
fromPage = int(from_page_text.value)
toPage = int(to_page_text.value)

downloader = DownloadFromDrive()
downloader._limit_size = float(max_download_size_text.value);
downloader.excluded_strings = [ext.strip() for ext in exclude_str_text.value.split(",") if ext.strip()]
downloader.copy_drive_to_drive(destDriveLink, sourceDriveLink, fromPage, toPage)
# Out:
# Total files: 1521
# [MK_04130.jpg] copied. Size 4.61 MB. Speed 2.08 MB/s
# [MK_04131.jpg] copied. Size 3.64 MB. Speed 1.47 MB/s
# [MK_04132.jpg] copied. Size 3.62 MB. Speed 1.68 MB/s
# [MK_04133.jpg] copied. Size 3.62 MB. Speed 1.59 MB/s
# [MK_04134.jpg] copied. Size 3.36 MB. Speed 1.68 MB/s
# [MK_04135.jpg] copied. Size 3.44 MB. Speed 1.39 MB/s
# [MK_04136.jpg] copied. Size 3.51 MB. Speed 1.40 MB/s
# [MK_04139.jpg] copied. Size 3.38 MB. Speed 1.28 MB/s
# [MK_04140.jpg] copied. Size 3.28 MB. Speed 1.43 MB/s
# [MK_04141.jpg] copied. Size 3.25 MB. Speed 1.50 MB/s
# [MK_04142.jpg] copied. Size 3.22 MB. Speed 1.15 MB/s
# [MK_04143.jpg] copied. Size 3.25 MB. Speed 1.58 MB/s
# [MK_04144.jpg] copied. Size 3.10 MB. Speed 1.43 MB/s
# [MK_04145.jpg] copied. Size 3.10 MB. Speed 1.54 MB/s
# [MK_04146.jpg] copied. Size 3.06 MB. Speed 1.24 MB/s
# [MK_04147.jpg] copied. Size 2.84 MB. Speed 1.24 MB/s
# [MK_04148.jpg] copied. Size 2.82 MB. Speed 1.02 MB/s
# [MK_04149.jpg] copied. Size 2.86 MB. Speed 1.43 MB/s
# [MK_04150.jpg] copied. Size 4.35 MB. Speed 2.04 MB/s
# [MK_04151.jpg] copied. Size 4.45 MB. Speed 0.87 MB/s
# [MK_04152.jpg] copied. Size 4.31 MB. Speed 1.36 MB/s
# [MK_04154.jpg] copied. Size 3.74 MB. Speed 1.56 MB/s
# [MK_04155.jpg] copied. Size 3.67 MB. Speed 1.61 MB/s
# [MK_04156.jpg] copied. Size 4.21 MB. Speed 2.15 MB/s
# [MK_04157.jpg] copied. Size 4.27 MB. Speed 1.97 MB/s
# [MK_04158.jpg] copied. Size 4.18 MB. Speed 1.89 MB/s
# [MK_04159.jpg] copied. Size 3.33 MB. Speed 1.51 MB/s
# [MK_04160.jpg] copied. Size 3.51 MB. Speed 1.64 MB/s
# [MK_04161.jpg] copied. Size 3.11 MB. Speed 1.41 MB/s
# [MK_04162.jpg] copied. Size 3.06 MB. Speed 1.40 MB/s
# [MK_04163.jpg] copied. Size 3.25 MB. Speed 1.45 MB/s
# [MK_04164.jpg] copied. Size 2.74 MB. Speed 1.26 MB/s
# [MK_04165.jpg] copied. Size 2.71 MB. Speed 1.28 MB/s
# [MK_04166.jpg] copied. Size 2.64 MB. Speed 1.33 MB/s
# [MK_04167.jpg] copied. Size 3.39 MB. Speed 1.67 MB/s
# [MK_04168.jpg] copied. Size 3.44 MB. Speed 1.69 MB/s
# [MK_04169.jpg] copied. Size 3.40 MB. Speed 1.65 MB/s
# [MK_04170.jpg] copied. Size 3.40 MB. Speed 1.84 MB/s
# [MK_04171.jpg] copied. Size 3.40 MB. Speed 1.58 MB/s
# [MK_04172.jpg] copied. Size 2.55 MB. Speed 1.30 MB/s
# [MK_04174.jpg] copied. Size 2.55 MB. Speed 1.20 MB/s
# [MK_04175.jpg] copied. Size 2.56 MB. Speed 1.21 MB/s
# [MK_04176.jpg] copied. Size 2.50 MB. Speed 1.18 MB/s
# [MK_04177.jpg] copied. Size 2.52 MB. Speed 0.69 MB/s
# [MK_04178.jpg] copied. Size 3.33 MB. Speed 1.33 MB/s
# [MK_04179.jpg] copied. Size 3.31 MB. Speed 1.30 MB/s
# [MK_04180.jpg] copied. Size 3.25 MB. Speed 1.26 MB/s
# [MK_04181.jpg] copied. Size 3.23 MB. Speed 1.63 MB/s
# [MK_04182.jpg] copied. Size 3.15 MB. Speed 0.83 MB/s
# [MK_04183.jpg] copied. Size 3.24 MB. Speed 1.22 MB/s
# [MK_04184.jpg] copied. Size 2.54 MB. Speed 0.62 MB/s
# [MK_04185.jpg] copied. Size 2.56 MB. Speed 1.16 MB/s
# [MK_04187.jpg] copied. Size 3.26 MB. Speed 1.56 MB/s
# [MK_04188.jpg] copied. Size 3.28 MB. Speed 1.63 MB/s
# [MK_04189.jpg] copied. Size 3.29 MB. Speed 1.36 MB/s
# [MK_04190.jpg] copied. Size 3.20 MB. Speed 1.53 MB/s
# [MK_04192.jpg] copied. Size 4.36 MB. Speed 2.31 MB/s
# [MK_04193.jpg] copied. Size 4.41 MB. Speed 2.17 MB/s
# [MK_04194.jpg] copied. Size 3.50 MB. Speed 1.15 MB/s
# [MK_04195.jpg] copied. Size 3.62 MB. Speed 1.82 MB/s
# [MK_04196.jpg] copied. Size 3.59 MB. Speed 1.64 MB/s
# [MK_04197.jpg] copied. Size 4.08 MB. Speed 1.64 MB/s
# [MK_04198.jpg] copied. Size 4.26 MB. Speed 1.77 MB/s
# [MK_04199.jpg] copied. Size 4.32 MB. Speed 1.82 MB/s
# [MK_04200.jpg] copied. Size 3.71 MB. Speed 1.68 MB/s
# [MK_04201.jpg] copied. Size 3.74 MB. Speed 2.06 MB/s
# [MK_04202.jpg] copied. Size 4.07 MB. Speed 2.06 MB/s
# [MK_04203.jpg] copied. Size 3.91 MB. Speed 1.60 MB/s
# [MK_04204.jpg] copied. Size 4.07 MB. Speed 1.31 MB/s
# [MK_04205.jpg] copied. Size 3.94 MB. Speed 1.84 MB/s
# [MK_04206.jpg] copied. Size 3.72 MB. Speed 1.06 MB/s
# [MK_04207.jpg] copied. Size 3.82 MB. Speed 1.89 MB/s
# [MK_04208.jpg] copied. Size 4.17 MB. Speed 1.98 MB/s
# [MK_04209.jpg] copied. Size 4.18 MB. Speed 1.92 MB/s
# [MK_04210.jpg] copied. Size 4.23 MB. Speed 1.40 MB/s
# [MK_04211.jpg] copied. Size 3.36 MB. Speed 1.67 MB/s
# [MK_04212.jpg] copied. Size 3.36 MB. Speed 1.74 MB/s
# [MK_04213.jpg] copied. Size 4.21 MB. Speed 1.52 MB/s
# [MK_04214.jpg] copied. Size 4.06 MB. Speed 1.99 MB/s
# [MK_04215.jpg] copied. Size 4.14 MB. Speed 2.14 MB/s
# [MK_04217.jpg] copied. Size 3.60 MB. Speed 1.90 MB/s
# [MK_04218.jpg] copied. Size 3.40 MB. Speed 1.57 MB/s
# [MK_04219.jpg] copied. Size 4.32 MB. Speed 1.79 MB/s
# [MK_04220.jpg] copied. Size 4.25 MB. Speed 2.22 MB/s
# [MK_04221.jpg] copied. Size 4.08 MB. Speed 1.24 MB/s
# [MK_04222.jpg] copied. Size 3.29 MB. Speed 1.48 MB/s
# [MK_04224.jpg] copied. Size 3.99 MB. Speed 1.69 MB/s
# [MK_04225.jpg] copied. Size 4.04 MB. Speed 1.23 MB/s
# [MK_04226.jpg] copied. Size 3.91 MB. Speed 1.24 MB/s
# [MK_04227.jpg] copied. Size 3.93 MB. Speed 2.04 MB/s
# [MK_04228.jpg] copied. Size 3.16 MB. Speed 0.99 MB/s
# [MK_04229.jpg] copied. Size 3.20 MB. Speed 1.39 MB/s
# [MK_04231.jpg] copied. Size 3.81 MB. Speed 1.71 MB/s
# [MK_04232.jpg] copied. Size 3.84 MB. Speed 1.85 MB/s
# [MK_04233.jpg] copied. Size 3.39 MB. Speed 1.00 MB/s
# [MK_04234.jpg] copied. Size 3.36 MB. Speed 1.32 MB/s
# [MK_04235.jpg] copied. Size 3.38 MB. Speed 1.64 MB/s
# [MK_04237.jpg] copied. Size 3.92 MB. Speed 1.80 MB/s
# [MK_04238.jpg] copied. Size 3.86 MB. Speed 0.63 MB/s
# [MK_04239.jpg] copied. Size 3.88 MB. Speed 1.27 MB/s
# [MK_04242.jpg] copied. Size 4.02 MB. Speed 1.66 MB/s
# [MK_04243.jpg] copied. Size 3.64 MB. Speed 1.75 MB/s
# [MK_04244.jpg] copied. Size 3.65 MB. Speed 1.88 MB/s
# [MK_04246.jpg] copied. Size 3.67 MB. Speed 1.64 MB/s
# [MK_04247.jpg] copied. Size 3.63 MB. Speed 1.52 MB/s
# [MK_04248.jpg] copied. Size 4.74 MB. Speed 1.91 MB/s
# [MK_04249.jpg] copied. Size 4.85 MB. Speed 2.21 MB/s
# [MK_04251.jpg] copied. Size 4.79 MB. Speed 2.15 MB/s
# [MK_04252.jpg] copied. Size 3.95 MB. Speed 1.43 MB/s
# [MK_04253.jpg] copied. Size 4.05 MB. Speed 0.99 MB/s
# [MK_04255.jpg] copied. Size 3.83 MB. Speed 1.65 MB/s
# [MK_04256.jpg] copied. Size 4.94 MB. Speed 2.23 MB/s
# [MK_04257.jpg] copied. Size 4.84 MB. Speed 1.91 MB/s
# [MK_04258.jpg] copied. Size 4.84 MB. Speed 2.17 MB/s
# [MK_04260.jpg] copied. Size 4.00 MB. Speed 1.72 MB/s
# [MK_04261.jpg] copied. Size 3.93 MB. Speed 1.97 MB/s
# [MK_04262.jpg] copied. Size 4.08 MB. Speed 1.93 MB/s
# [MK_04263.jpg] copied. Size 4.09 MB. Speed 1.94 MB/s
# [MK_04264.jpg] copied. Size 4.05 MB. Speed 1.68 MB/s
# [MK_04265.jpg] copied. Size 4.06 MB. Speed 1.87 MB/s
# [MK_04266.jpg] copied. Size 4.08 MB. Speed 1.82 MB/s
# [MK_04267.jpg] copied. Size 4.07 MB. Speed 2.14 MB/s
# [MK_04268.jpg] copied. Size 2.96 MB. Speed 1.35 MB/s
# [MK_04269.jpg] copied. Size 3.14 MB. Speed 1.33 MB/s
# [MK_04270.jpg] copied. Size 3.06 MB. Speed 1.38 MB/s
# [MK_04271.jpg] copied. Size 4.19 MB. Speed 1.80 MB/s
# [MK_04272.jpg] copied. Size 4.21 MB. Speed 2.11 MB/s
# [MK_04273.jpg] copied. Size 4.28 MB. Speed 2.14 MB/s
# [MK_04274.jpg] copied. Size 3.92 MB. Speed 1.12 MB/s
# [MK_04275.jpg] copied. Size 3.84 MB. Speed 1.86 MB/s
# [MK_04277.jpg] copied. Size 4.20 MB. Speed 1.78 MB/s
# [MK_04278.jpg] copied. Size 4.21 MB. Speed 1.66 MB/s
# [MK_04279.jpg] copied. Size 3.44 MB. Speed 1.72 MB/s
# [MK_04280.jpg] copied. Size 3.44 MB. Speed 1.60 MB/s
# [MK_04282.jpg] copied. Size 3.11 MB. Speed 1.51 MB/s
# [MK_04284.jpg] copied. Size 4.32 MB. Speed 1.70 MB/s
# [MK_04285.jpg] copied. Size 4.44 MB. Speed 1.83 MB/s
# [MK_04286.jpg] copied. Size 4.35 MB. Speed 2.07 MB/s
# [MK_04287.jpg] copied. Size 3.95 MB. Speed 1.86 MB/s
# [MK_04289.jpg] copied. Size 3.91 MB. Speed 2.18 MB/s
# [MK_04290.jpg] copied. Size 4.32 MB. Speed 2.26 MB/s
# [MK_04293.jpg] copied. Size 4.43 MB. Speed 1.86 MB/s
# [MK_04294.jpg] copied. Size 4.43 MB. Speed 1.86 MB/s
# [MK_04296.jpg] copied. Size 3.66 MB. Speed 1.73 MB/s
# [MK_04297.jpg] copied. Size 3.61 MB. Speed 1.68 MB/s
# [MK_04298.jpg] copied. Size 3.69 MB. Speed 2.03 MB/s
# [MK_04299.jpg] copied. Size 3.66 MB. Speed 1.50 MB/s
# [MK_04300.jpg] copied. Size 3.77 MB. Speed 1.90 MB/s
# [MK_04301.jpg] copied. Size 4.14 MB. Speed 2.08 MB/s
# [MK_04302.jpg] copied. Size 4.07 MB. Speed 1.44 MB/s
# [MK_04303.jpg] copied. Size 3.61 MB. Speed 1.93 MB/s
# [MK_04304.jpg] copied. Size 3.69 MB. Speed 1.87 MB/s
# [MK_04305.jpg] copied. Size 3.65 MB. Speed 1.49 MB/s
# [MK_04306.jpg] copied. Size 3.12 MB. Speed 1.59 MB/s
# [MK_04308.jpg] copied. Size 3.16 MB. Speed 1.64 MB/s
# [MK_04309.jpg] copied. Size 3.17 MB. Speed 1.53 MB/s
# [MK_04311.jpg] copied. Size 3.86 MB. Speed 1.93 MB/s
# [MK_04312.jpg] copied. Size 3.99 MB. Speed 2.14 MB/s
# [MK_04313.jpg] copied. Size 3.61 MB. Speed 1.88 MB/s
# [MK_04314.jpg] copied. Size 3.71 MB. Speed 1.88 MB/s
# [MK_04315.jpg] copied. Size 3.77 MB. Speed 1.64 MB/s
# [MK_04316.jpg] copied. Size 3.70 MB. Speed 1.82 MB/s
# [MK_04317.jpg] copied. Size 3.72 MB. Speed 1.79 MB/s
# [MK_04318.jpg] copied. Size 3.64 MB. Speed 1.89 MB/s
# [MK_04319.jpg] copied. Size 3.68 MB. Speed 0.34 MB/s
# [MK_04320.jpg] copied. Size 3.58 MB. Speed 1.73 MB/s
# [MK_04321.jpg] copied. Size 3.73 MB. Speed 1.40 MB/s
# [MK_04322.jpg] copied. Size 4.00 MB. Speed 2.14 MB/s
# [MK_04323.jpg] copied. Size 3.95 MB. Speed 1.82 MB/s
# [MK_04324.jpg] copied. Size 3.69 MB. Speed 1.70 MB/s
# [MK_04325.jpg] copied. Size 3.89 MB. Speed 1.37 MB/s
# [MK_04326.jpg] copied. Size 3.83 MB. Speed 1.80 MB/s
# [MK_04327.jpg] copied. Size 3.60 MB. Speed 1.76 MB/s
# [MK_04328.jpg] copied. Size 3.91 MB. Speed 1.55 MB/s
# [MK_04329.jpg] copied. Size 2.92 MB. Speed 1.49 MB/s
# [MK_04330.jpg] copied. Size 2.97 MB. Speed 1.46 MB/s
# [MK_04332.jpg] copied. Size 4.47 MB. Speed 1.89 MB/s
# [MK_04333.jpg] copied. Size 4.49 MB. Speed 2.21 MB/s
# [MK_04334.jpg] copied. Size 4.32 MB. Speed 2.07 MB/s
# [MK_04335.jpg] copied. Size 4.51 MB. Speed 2.31 MB/s
# [MK_04336.jpg] copied. Size 3.24 MB. Speed 1.28 MB/s
# [MK_04337.jpg] copied. Size 3.23 MB. Speed 1.45 MB/s
# [MK_04338.jpg] copied. Size 3.24 MB. Speed 1.71 MB/s
# [MK_04339.jpg] copied. Size 3.24 MB. Speed 0.75 MB/s
# [MK_04340.jpg] copied. Size 3.21 MB. Speed 1.56 MB/s
# [MK_04341.jpg] copied. Size 3.20 MB. Speed 1.40 MB/s
# [MK_04342.jpg] copied. Size 3.48 MB. Speed 1.52 MB/s
# [MK_04344.jpg] copied. Size 3.45 MB. Speed 1.65 MB/s
# [MK_04345.jpg] copied. Size 3.97 MB. Speed 1.82 MB/s
# [MK_04346.jpg] copied. Size 4.04 MB. Speed 1.92 MB/s
# [MK_04347.jpg] copied. Size 3.95 MB. Speed 1.52 MB/s
# [MK_04348.jpg] copied. Size 4.05 MB. Speed 1.67 MB/s
# [MK_04349.jpg] copied. Size 3.45 MB. Speed 1.84 MB/s
# [MK_04350.jpg] copied. Size 3.33 MB. Speed 1.33 MB/s
# [MK_04351.jpg] copied. Size 3.47 MB. Speed 1.66 MB/s
# [MK_04352.jpg] copied. Size 3.30 MB. Speed 1.69 MB/s
# [MK_04353.jpg] copied. Size 3.36 MB. Speed 1.57 MB/s
# [MK_04354.jpg] copied. Size 4.06 MB. Speed 2.04 MB/s
# [MK_04355.jpg] copied. Size 4.11 MB. Speed 1.77 MB/s
# [MK_04356.jpg] copied. Size 4.03 MB. Speed 1.26 MB/s
# [MK_04357.jpg] copied. Size 4.05 MB. Speed 1.58 MB/s
# [MK_04358.jpg] copied. Size 3.96 MB. Speed 2.18 MB/s
# [MK_04359.jpg] copied. Size 4.01 MB. Speed 0.66 MB/s
# [MK_04360.jpg] copied. Size 3.89 MB. Speed 1.81 MB/s
# [MK_04361.jpg] copied. Size 3.45 MB. Speed 1.44 MB/s
# [MK_04362.jpg] copied. Size 3.46 MB. Speed 1.63 MB/s
# [MK_04364.jpg] copied. Size 4.10 MB. Speed 1.77 MB/s
# [MK_04365.jpg] copied. Size 4.18 MB. Speed 1.05 MB/s
# [MK_04366.jpg] copied. Size 4.09 MB. Speed 1.80 MB/s
# [MK_04367.jpg] copied. Size 3.66 MB. Speed 1.51 MB/s
# [MK_04368.jpg] copied. Size 3.68 MB. Speed 1.83 MB/s
# [MK_04369.jpg] copied. Size 3.68 MB. Speed 1.97 MB/s
# [MK_04371.jpg] copied. Size 3.95 MB. Speed 1.64 MB/s
# [MK_04372.jpg] copied. Size 4.03 MB. Speed 2.04 MB/s
# [MK_04373.jpg] copied. Size 4.06 MB. Speed 2.08 MB/s
# [MK_04374.jpg] copied. Size 3.41 MB. Speed 2.03 MB/s
# [MK_04375.jpg] copied. Size 3.42 MB. Speed 1.93 MB/s
# [MK_04376.jpg] copied. Size 3.42 MB. Speed 1.72 MB/s
# [MK_04377.jpg] copied. Size 3.88 MB. Speed 1.43 MB/s
# [MK_04379.jpg] copied. Size 3.82 MB. Speed 1.91 MB/s
# [MK_04380.jpg] copied. Size 3.63 MB. Speed 1.60 MB/s
# [MK_04381.jpg] copied. Size 3.67 MB. Speed 2.02 MB/s
# [MK_04382.jpg] copied. Size 3.73 MB. Speed 1.56 MB/s
# [MK_04383.jpg] copied. Size 3.07 MB. Speed 1.42 MB/s
# [MK_04384.jpg] copied. Size 3.02 MB. Speed 1.50 MB/s
# [MK_04385.jpg] copied. Size 3.01 MB. Speed 1.52 MB/s
# [MK_04386.jpg] copied. Size 4.63 MB. Speed 2.52 MB/s
# [MK_04387.jpg] copied. Size 4.74 MB. Speed 1.92 MB/s
# [MK_04389.jpg] copied. Size 4.66 MB. Speed 2.20 MB/s
# [MK_04391.jpg] copied. Size 3.50 MB. Speed 1.77 MB/s
# [MK_04392.jpg] copied. Size 3.60 MB. Speed 1.93 MB/s
# [MK_04393.jpg] copied. Size 3.52 MB. Speed 1.73 MB/s
# [MK_04394.jpg] copied. Size 3.94 MB. Speed 1.41 MB/s
# [MK_04395.jpg] copied. Size 4.03 MB. Speed 2.04 MB/s
# [MK_04396.jpg] copied. Size 4.07 MB. Speed 2.01 MB/s
# [MK_04398.jpg] copied. Size 3.99 MB. Speed 2.08 MB/s
# [MK_04399.jpg] copied. Size 4.04 MB. Speed 2.03 MB/s
# [MK_04400.jpg] copied. Size 3.42 MB. Speed 1.87 MB/s
# [MK_04402.jpg] copied. Size 3.51 MB. Speed 1.61 MB/s
# [MK_04403.jpg] copied. Size 3.51 MB. Speed 1.82 MB/s
# [MK_04404.jpg] copied. Size 3.75 MB. Speed 1.64 MB/s
# [MK_04405.jpg] copied. Size 3.78 MB. Speed 2.09 MB/s
# [MK_04406.jpg] copied. Size 3.29 MB. Speed 1.56 MB/s
# [MK_04407.jpg] copied. Size 3.37 MB. Speed 1.14 MB/s
# [MK_04409.jpg] copied. Size 3.29 MB. Speed 1.35 MB/s
# [MK_04410.jpg] copied. Size 3.22 MB. Speed 1.54 MB/s
# [MK_04411.jpg] copied. Size 4.04 MB. Speed 2.23 MB/s
# [MK_04412.jpg] copied. Size 4.04 MB. Speed 1.47 MB/s
# [MK_04413.jpg] copied. Size 4.03 MB. Speed 1.79 MB/s
# [MK_04414.jpg] copied. Size 5.45 MB. Speed 2.78 MB/s
# [MK_04417.jpg] copied. Size 5.21 MB. Speed 1.20 MB/s
# [MK_04418.jpg] copied. Size 4.19 MB. Speed 2.06 MB/s
# [MK_04419.jpg] copied. Size 4.15 MB. Speed 2.08 MB/s
# [MK_04420.jpg] copied. Size 4.05 MB. Speed 2.02 MB/s
# [MK_04421.jpg] copied. Size 5.44 MB. Speed 2.91 MB/s
# [MK_04422.jpg] copied. Size 5.48 MB. Speed 1.90 MB/s
# [MK_04423.jpg] copied. Size 5.52 MB. Speed 2.50 MB/s
# [MK_04424.jpg] copied. Size 5.53 MB. Speed 2.91 MB/s
# [MK_04425.jpg] copied. Size 5.52 MB. Speed 2.52 MB/s
# [MK_04426.jpg] copied. Size 4.12 MB. Speed 1.71 MB/s
# [MK_04428.jpg] copied. Size 4.11 MB. Speed 2.16 MB/s
# [MK_04429.jpg] copied. Size 4.14 MB. Speed 1.97 MB/s
# [MK_04430.jpg] copied. Size 4.88 MB. Speed 2.30 MB/s
# [MK_04431.jpg] copied. Size 4.95 MB. Speed 2.50 MB/s
# [MK_04432.jpg] copied. Size 4.86 MB. Speed 2.12 MB/s
# [MK_04433.jpg] copied. Size 4.91 MB. Speed 1.73 MB/s
# [MK_04434.jpg] copied. Size 3.93 MB. Speed 2.02 MB/s
# [MK_04436.jpg] copied. Size 3.90 MB. Speed 1.78 MB/s
# [MK_04437.jpg] copied. Size 4.39 MB. Speed 1.50 MB/s
# [MK_04438.jpg] copied. Size 4.45 MB. Speed 2.27 MB/s
# [MK_04439.jpg] copied. Size 4.37 MB. Speed 1.85 MB/s
# [MK_04440.jpg] copied. Size 4.03 MB. Speed 2.12 MB/s
# [MK_04441.jpg] copied. Size 3.89 MB. Speed 0.77 MB/s
# [MK_04442.jpg] copied. Size 3.95 MB. Speed 1.89 MB/s
# [MK_04443.jpg] copied. Size 4.09 MB. Speed 1.88 MB/s
# [MK_04445.jpg] copied. Size 4.02 MB. Speed 2.43 MB/s
# [MK_04446.jpg] copied. Size 4.02 MB. Speed 1.37 MB/s
# [MK_04447.jpg] copied. Size 4.61 MB. Speed 2.34 MB/s
# [MK_04448.jpg] copied. Size 4.66 MB. Speed 2.57 MB/s
# [MK_04449.jpg] copied. Size 4.64 MB. Speed 1.33 MB/s
# [MK_04450.jpg] copied. Size 3.86 MB. Speed 2.00 MB/s
# [MK_04451.jpg] copied. Size 3.85 MB. Speed 1.79 MB/s
# [MK_04452.jpg] copied. Size 3.87 MB. Speed 2.27 MB/s
# [MK_04454.jpg] copied. Size 4.78 MB. Speed 1.39 MB/s
# [MK_04456.jpg] copied. Size 4.63 MB. Speed 1.31 MB/s
# [MK_04457.jpg] copied. Size 4.69 MB. Speed 2.62 MB/s
# [MK_04458.jpg] copied. Size 4.61 MB. Speed 2.42 MB/s
# [MK_04459.jpg] copied. Size 4.15 MB. Speed 1.53 MB/s
# [MK_04461.jpg] copied. Size 4.08 MB. Speed 1.64 MB/s
# [MK_04463.jpg] copied. Size 4.06 MB. Speed 1.99 MB/s
# [MK_04464.jpg] copied. Size 4.07 MB. Speed 2.12 MB/s
# [MK_04466.jpg] copied. Size 4.50 MB. Speed 2.37 MB/s
# [MK_04467.jpg] copied. Size 4.51 MB. Speed 2.53 MB/s
# [MK_04469.jpg] copied. Size 3.95 MB. Speed 2.18 MB/s
# [MK_04470.jpg] copied. Size 3.96 MB. Speed 1.78 MB/s
# [MK_04471.jpg] copied. Size 3.94 MB. Speed 2.06 MB/s
# [MK_04472.jpg] copied. Size 4.49 MB. Speed 2.31 MB/s
# [MK_04473.jpg] copied. Size 4.57 MB. Speed 2.35 MB/s
# [MK_04474.jpg] copied. Size 4.52 MB. Speed 2.10 MB/s
# [MK_04475.jpg] copied. Size 4.09 MB. Speed 2.16 MB/s
# [MK_04477.jpg] copied. Size 4.00 MB. Speed 2.05 MB/s
# [MK_04478.jpg] copied. Size 3.88 MB. Speed 2.13 MB/s
# [MK_04479.jpg] copied. Size 3.94 MB. Speed 2.27 MB/s
# [MK_04480.jpg] copied. Size 3.94 MB. Speed 1.75 MB/s
# [MK_04483.jpg] copied. Size 5.03 MB. Speed 2.39 MB/s
# [MK_04484.jpg] copied. Size 5.18 MB. Speed 2.74 MB/s
# [MK_04485.jpg] copied. Size 5.10 MB. Speed 2.48 MB/s
# [MK_04486.jpg] copied. Size 5.20 MB. Speed 2.12 MB/s
# [MK_04487.jpg] copied. Size 4.15 MB. Speed 1.52 MB/s
# [MK_04488.jpg] copied. Size 4.16 MB. Speed 2.07 MB/s
# [MK_04489.jpg] copied. Size 4.16 MB. Speed 1.92 MB/s
# [MK_04491.jpg] copied. Size 4.20 MB. Speed 1.97 MB/s
# [MK_04492.jpg] copied. Size 4.16 MB. Speed 1.91 MB/s
# [MK_04493.jpg] copied. Size 4.18 MB. Speed 0.90 MB/s
# [MK_04494.jpg] copied. Size 4.13 MB. Speed 1.82 MB/s
# [MK_04495.jpg] copied. Size 4.18 MB. Speed 2.45 MB/s
# [MK_04496.jpg] copied. Size 3.68 MB. Speed 1.97 MB/s
# [MK_04497.jpg] copied. Size 3.58 MB. Speed 1.43 MB/s
# [MK_04498.jpg] copied. Size 3.56 MB. Speed 1.72 MB/s
# [MK_04499.jpg] copied. Size 3.86 MB. Speed 1.64 MB/s
# [MK_04500.jpg] copied. Size 3.99 MB. Speed 1.59 MB/s
# [MK_04501.jpg] copied. Size 4.48 MB. Speed 2.31 MB/s
# [MK_04502.jpg] copied. Size 4.47 MB. Speed 2.28 MB/s
# [MK_04503.jpg] copied. Size 4.49 MB. Speed 2.22 MB/s
# [MK_04504.jpg] copied. Size 4.46 MB. Speed 1.75 MB/s
# [MK_04505.jpg] copied. Size 4.27 MB. Speed 1.84 MB/s
# [MK_04507.jpg] copied. Size 4.44 MB. Speed 1.63 MB/s
# [MK_04508.jpg] copied. Size 4.02 MB. Speed 1.89 MB/s
# [MK_04510.jpg] copied. Size 3.67 MB. Speed 1.65 MB/s
# [MK_04511.jpg] copied. Size 3.68 MB. Speed 1.09 MB/s
# [MK_04512.jpg] copied. Size 4.18 MB. Speed 2.00 MB/s
# [MK_04513.jpg] copied. Size 4.08 MB. Speed 2.01 MB/s
# [MK_04514.jpg] copied. Size 4.29 MB. Speed 2.19 MB/s
# [MK_04515.jpg] copied. Size 4.39 MB. Speed 2.08 MB/s
# [MK_04516.jpg] copied. Size 4.37 MB. Speed 1.53 MB/s
# [MK_04518.jpg] copied. Size 5.12 MB. Speed 2.26 MB/s
# [MK_04519.jpg] copied. Size 5.13 MB. Speed 2.44 MB/s
# [MK_04520.jpg] copied. Size 5.18 MB. Speed 1.09 MB/s
# [MK_04522.jpg] copied. Size 4.13 MB. Speed 1.89 MB/s
# [MK_04523.jpg] copied. Size 4.06 MB. Speed 2.02 MB/s
# [MK_04524.jpg] copied. Size 4.07 MB. Speed 1.70 MB/s
# [MK_04525.jpg] copied. Size 4.58 MB. Speed 2.21 MB/s
# [MK_04526.jpg] copied. Size 4.68 MB. Speed 2.18 MB/s
# [MK_04527.jpg] copied. Size 4.63 MB. Speed 2.29 MB/s
# [MK_04528.jpg] copied. Size 4.65 MB. Speed 2.43 MB/s
# [MK_04529.jpg] copied. Size 3.99 MB. Speed 1.92 MB/s
# [MK_04532.jpg] copied. Size 4.04 MB. Speed 1.87 MB/s
# [MK_04533.jpg] copied. Size 4.67 MB. Speed 1.02 MB/s
# [MK_04534.jpg] copied. Size 4.73 MB. Speed 2.55 MB/s
# [MK_04536.jpg] copied. Size 4.80 MB. Speed 1.73 MB/s
# [MK_04537.jpg] copied. Size 4.15 MB. Speed 1.89 MB/s
# [MK_04539.jpg] copied. Size 4.14 MB. Speed 2.31 MB/s
# [MK_04540.jpg] copied. Size 4.12 MB. Speed 1.92 MB/s
# [MK_04542.jpg] copied. Size 4.59 MB. Speed 1.93 MB/s
# [MK_04543.jpg] copied. Size 4.57 MB. Speed 2.08 MB/s
# [MK_04544.jpg] copied. Size 4.01 MB. Speed 2.06 MB/s
# [MK_04545.jpg] copied. Size 3.82 MB. Speed 1.29 MB/s
# [MK_04546.jpg] copied. Size 3.90 MB. Speed 2.05 MB/s
# [MK_04548.jpg] copied. Size 3.86 MB. Speed 1.59 MB/s
# [MK_04549.jpg] copied. Size 3.90 MB. Speed 1.62 MB/s
# [MK_04550.jpg] copied. Size 3.88 MB. Speed 1.85 MB/s
# [MK_04551.jpg] copied. Size 4.27 MB. Speed 2.14 MB/s
# [MK_04552.jpg] copied. Size 13.77 MB. Speed 4.83 MB/s
# [MK_04553.jpg] copied. Size 13.58 MB. Speed 3.62 MB/s
# [MK_04554.jpg] copied. Size 12.97 MB. Speed 4.17 MB/s
# [MK_04555.jpg] copied. Size 12.92 MB. Speed 5.61 MB/s
# [MK_04558.jpg] copied. Size 14.96 MB. Speed 6.18 MB/s
# [MK_04559.jpg] copied. Size 14.96 MB. Speed 1.85 MB/s
# [MK_04560.jpg] copied. Size 15.00 MB. Speed 5.75 MB/s
# [MK_04561.jpg] copied. Size 14.72 MB. Speed 5.91 MB/s
# [MK_04563.jpg] copied. Size 12.82 MB. Speed 5.00 MB/s
# [MK_04564.jpg] copied. Size 12.85 MB. Speed 5.06 MB/s
# [MK_04565.jpg] copied. Size 12.95 MB. Speed 4.13 MB/s
# [MK_04566.jpg] copied. Size 12.91 MB. Speed 4.03 MB/s
# [MK_04568.jpg] copied. Size 11.85 MB. Speed 1.37 MB/s
# [MK_04569.jpg] copied. Size 12.10 MB. Speed 4.71 MB/s
# [MK_04570.jpg] copied. Size 12.25 MB. Speed 4.67 MB/s
# [MK_04571.jpg] copied. Size 11.91 MB. Speed 5.23 MB/s
# [MK_04572.jpg] copied. Size 11.94 MB. Speed 4.96 MB/s
# [MK_04573.jpg] copied. Size 11.85 MB. Speed 4.11 MB/s
# [MK_04574.jpg] copied. Size 13.07 MB. Speed 5.45 MB/s
# [MK_04576.jpg] copied. Size 13.23 MB. Speed 4.35 MB/s
# [MK_04577.jpg] copied. Size 13.27 MB. Speed 4.87 MB/s
# [MK_04578.jpg] copied. Size 14.16 MB. Speed 5.76 MB/s
# [MK_04579.jpg] copied. Size 14.14 MB. Speed 4.54 MB/s
# [MK_04580.jpg] copied. Size 14.05 MB. Speed 5.52 MB/s
# [MK_04582.jpg] copied. Size 14.18 MB. Speed 5.04 MB/s
# [MK_04584.jpg] copied. Size 13.52 MB. Speed 5.36 MB/s
# [MK_04585.jpg] copied. Size 13.65 MB. Speed 5.13 MB/s
# [MK_04586.jpg] copied. Size 13.68 MB. Speed 5.59 MB/s
# [MK_04587.jpg] copied. Size 13.58 MB. Speed 5.22 MB/s
# [MK_04588.jpg] copied. Size 13.43 MB. Speed 1.16 MB/s
# [MK_04589.jpg] copied. Size 13.69 MB. Speed 5.72 MB/s
# [MK_04591.jpg] copied. Size 14.04 MB. Speed 4.72 MB/s
# [MK_04592.jpg] copied. Size 14.64 MB. Speed 1.58 MB/s
# [MK_04593.jpg] copied. Size 14.55 MB. Speed 6.09 MB/s
# [MK_04594.jpg] copied. Size 14.57 MB. Speed 4.77 MB/s
# [MK_04595.jpg] copied. Size 14.58 MB. Speed 5.50 MB/s
# [MK_04596.jpg] copied. Size 11.96 MB. Speed 2.89 MB/s
# [MK_04598.jpg] copied. Size 11.75 MB. Speed 4.28 MB/s
# [MK_04600.jpg] copied. Size 11.86 MB. Speed 4.47 MB/s
# [MK_04601.jpg] copied. Size 13.54 MB. Speed 5.19 MB/s
# [MK_04602.jpg] copied. Size 13.69 MB. Speed 4.78 MB/s
# [MK_04604.jpg] copied. Size 13.42 MB. Speed 5.03 MB/s
# [MK_04605.jpg] copied. Size 13.21 MB. Speed 5.11 MB/s
# [MK_04606.jpg] copied. Size 13.00 MB. Speed 3.74 MB/s
# [MK_04608.jpg] copied. Size 12.33 MB. Speed 4.72 MB/s
# [MK_04609.jpg] copied. Size 12.49 MB. Speed 4.78 MB/s
# [MK_04610.jpg] copied. Size 12.47 MB. Speed 4.26 MB/s
# [MK_04611.jpg] copied. Size 12.31 MB. Speed 4.74 MB/s
# [MK_04612.jpg] copied. Size 12.31 MB. Speed 3.22 MB/s
# [MK_04613.jpg] copied. Size 12.12 MB. Speed 2.12 MB/s
# [MK_04614.jpg] copied. Size 12.47 MB. Speed 4.50 MB/s
# [MK_04615.jpg] copied. Size 12.78 MB. Speed 5.01 MB/s
# [MK_04616.jpg] copied. Size 12.70 MB. Speed 5.89 MB/s
# [MK_04620.jpg] copied. Size 14.25 MB. Speed 5.24 MB/s
# [MK_04621.jpg] copied. Size 14.03 MB. Speed 6.16 MB/s
# [MK_04622.jpg] copied. Size 14.18 MB. Speed 5.74 MB/s
# [MK_04623.jpg] copied. Size 12.29 MB. Speed 5.04 MB/s
# [MK_04624.jpg] copied. Size 12.07 MB. Speed 4.68 MB/s
# [MK_04626.jpg] copied. Size 12.28 MB. Speed 3.09 MB/s
# [MK_04627.jpg] copied. Size 12.31 MB. Speed 4.61 MB/s
# [MK_04628.jpg] copied. Size 12.18 MB. Speed 4.17 MB/s
# [MK_04630.jpg] copied. Size 11.04 MB. Speed 4.08 MB/s
# [MK_04631.jpg] copied. Size 11.67 MB. Speed 4.29 MB/s
# [MK_04632.jpg] copied. Size 11.68 MB. Speed 4.99 MB/s
# [MK_04633.jpg] copied. Size 11.96 MB. Speed 1.83 MB/s
# [MK_04634.jpg] copied. Size 13.27 MB. Speed 4.95 MB/s
# [MK_04635.jpg] copied. Size 13.23 MB. Speed 3.73 MB/s
# [MK_04636.jpg] copied. Size 13.22 MB. Speed 1.81 MB/s
# [MK_04638.jpg] copied. Size 13.28 MB. Speed 3.30 MB/s
# [MK_04639.jpg] copied. Size 13.25 MB. Speed 5.03 MB/s
# [MK_04640.jpg] copied. Size 13.37 MB. Speed 5.33 MB/s
# [MK_04641.jpg] copied. Size 11.46 MB. Speed 3.91 MB/s
# [MK_04642.jpg] copied. Size 11.72 MB. Speed 3.84 MB/s
# [MK_04643.jpg] copied. Size 11.79 MB. Speed 5.02 MB/s
# [MK_04645.jpg] copied. Size 11.60 MB. Speed 2.58 MB/s
# [MK_04646.jpg] copied. Size 13.05 MB. Speed 5.73 MB/s
# [MK_04647.jpg] copied. Size 13.62 MB. Speed 6.08 MB/s
# [MK_04648.jpg] copied. Size 13.63 MB. Speed 5.16 MB/s
# [MK_04649.jpg] copied. Size 13.55 MB. Speed 5.42 MB/s
# [MK_04650.jpg] copied. Size 12.30 MB. Speed 5.19 MB/s
# [MK_04652.jpg] copied. Size 12.26 MB. Speed 2.23 MB/s
# [MK_04653.jpg] copied. Size 12.26 MB. Speed 1.99 MB/s
# [MK_04654.jpg] copied. Size 14.60 MB. Speed 6.52 MB/s
# [MK_04655.jpg] copied. Size 14.67 MB. Speed 6.16 MB/s
# [MK_04656.jpg] copied. Size 14.36 MB. Speed 6.79 MB/s
# [MK_04657.jpg] copied. Size 14.15 MB. Speed 5.96 MB/s
# [MK_04658.jpg] copied. Size 14.35 MB. Speed 5.78 MB/s
# [MK_04660.jpg] copied. Size 11.90 MB. Speed 5.13 MB/s
# [MK_04661.jpg] copied. Size 11.88 MB. Speed 5.15 MB/s
# [MK_04662.jpg] copied. Size 12.04 MB. Speed 3.86 MB/s
# [MK_04663.jpg] copied. Size 12.00 MB. Speed 5.14 MB/s
# [MK_04664.jpg] copied. Size 12.89 MB. Speed 5.14 MB/s
# [MK_04665.jpg] copied. Size 13.18 MB. Speed 6.07 MB/s
# [MK_04667.jpg] copied. Size 12.92 MB. Speed 4.29 MB/s
# [MK_04668.jpg] copied. Size 11.28 MB. Speed 4.83 MB/s
# [MK_04669.jpg] copied. Size 11.25 MB. Speed 4.63 MB/s
# [MK_04670.jpg] copied. Size 11.27 MB. Speed 4.15 MB/s
# [MK_04671.jpg] copied. Size 11.23 MB. Speed 4.69 MB/s
# [MK_04673.jpg] copied. Size 11.17 MB. Speed 5.30 MB/s
# [MK_04674.jpg] copied. Size 13.24 MB. Speed 1.54 MB/s
# [MK_04675.jpg] copied. Size 13.16 MB. Speed 5.32 MB/s
# [MK_04676.jpg] copied. Size 13.17 MB. Speed 4.09 MB/s
# [MK_04677.jpg] copied. Size 13.08 MB. Speed 4.93 MB/s
# [MK_04679.jpg] copied. Size 11.32 MB. Speed 4.02 MB/s
# [MK_04680.jpg] copied. Size 11.51 MB. Speed 4.21 MB/s
# [MK_04681.jpg] copied. Size 11.51 MB. Speed 4.32 MB/s
# [MK_04682.jpg] copied. Size 11.44 MB. Speed 3.35 MB/s
# [MK_04683.jpg] copied. Size 11.33 MB. Speed 4.68 MB/s
# [MK_04685.jpg] copied. Size 11.57 MB. Speed 4.53 MB/s
# [MK_04686.jpg] copied. Size 11.56 MB. Speed 4.39 MB/s
# [MK_04687.jpg] copied. Size 10.99 MB. Speed 3.81 MB/s
# [MK_04688.jpg] copied. Size 10.44 MB. Speed 5.12 MB/s
# [MK_04689.jpg] copied. Size 10.59 MB. Speed 3.86 MB/s
# [MK_04692.jpg] copied. Size 12.54 MB. Speed 4.61 MB/s
# [MK_04693.jpg] copied. Size 10.39 MB. Speed 4.46 MB/s
# [MK_04694.jpg] copied. Size 10.79 MB. Speed 1.96 MB/s
# [MK_04695.jpg] copied. Size 10.78 MB. Speed 4.53 MB/s
# [MK_04696.jpg] copied. Size 13.71 MB. Speed 5.22 MB/s
# [MK_04697.jpg] copied. Size 13.71 MB. Speed 4.80 MB/s
# [MK_04699.jpg] copied. Size 13.67 MB. Speed 5.42 MB/s
# [MK_04700.jpg] copied. Size 12.56 MB. Speed 5.96 MB/s
# [MK_04701.jpg] copied. Size 12.72 MB. Speed 5.64 MB/s
# [MK_04702.jpg] copied. Size 12.76 MB. Speed 5.53 MB/s
# [MK_04703.jpg] copied. Size 12.81 MB. Speed 5.97 MB/s
# [MK_04705.jpg] copied. Size 14.69 MB. Speed 5.65 MB/s
# [MK_04706.jpg] copied. Size 14.78 MB. Speed 6.56 MB/s
# [MK_04707.jpg] copied. Size 14.24 MB. Speed 6.03 MB/s
# [MK_04708.jpg] copied. Size 14.19 MB. Speed 5.90 MB/s
# [MK_04709.jpg] copied. Size 13.84 MB. Speed 6.45 MB/s
# [MK_04711.jpg] copied. Size 13.05 MB. Speed 4.87 MB/s
# [MK_04712.jpg] copied. Size 13.19 MB. Speed 5.43 MB/s
# [MK_04713.jpg] copied. Size 13.23 MB. Speed 5.35 MB/s
# [MK_04714.jpg] copied. Size 13.06 MB. Speed 5.99 MB/s
# [MK_04715.jpg] copied. Size 13.07 MB. Speed 5.26 MB/s
# [MK_04716.jpg] copied. Size 13.10 MB. Speed 5.88 MB/s
# [MK_04717.jpg] copied. Size 12.54 MB. Speed 4.50 MB/s
# [MK_04719.jpg] copied. Size 13.47 MB. Speed 5.53 MB/s
# [MK_04720.jpg] copied. Size 13.68 MB. Speed 3.82 MB/s
# [MK_04721.jpg] copied. Size 13.63 MB. Speed 5.73 MB/s
# [MK_04722.jpg] copied. Size 13.49 MB. Speed 5.45 MB/s
# [MK_04723.jpg] copied. Size 12.46 MB. Speed 4.46 MB/s
# [MK_04724.jpg] copied. Size 12.52 MB. Speed 4.55 MB/s
# [MK_04726.jpg] copied. Size 13.22 MB. Speed 2.24 MB/s
# [MK_04727.jpg] copied. Size 13.22 MB. Speed 3.01 MB/s
# [MK_04733.jpg] copied. Size 18.62 MB. Speed 8.37 MB/s
# [MK_04735.jpg] copied. Size 17.93 MB. Speed 6.35 MB/s
# [MK_04737.jpg] copied. Size 17.12 MB. Speed 2.81 MB/s
# [MK_04739.jpg] copied. Size 17.93 MB. Speed 6.13 MB/s
# [MK_04741.jpg] copied. Size 19.28 MB. Speed 7.75 MB/s
# [MK_04743.jpg] copied. Size 17.20 MB. Speed 5.07 MB/s
# [MK_04745.jpg] copied. Size 17.54 MB. Speed 3.45 MB/s
# [MK_04747.jpg] copied. Size 16.86 MB. Speed 4.75 MB/s
# [MK_04749.jpg] copied. Size 15.68 MB. Speed 5.12 MB/s
# [MK_04751.jpg] copied. Size 15.25 MB. Speed 5.00 MB/s
# [MK_04753.jpg] copied. Size 15.23 MB. Speed 5.55 MB/s
# [MK_04755.jpg] copied. Size 16.06 MB. Speed 2.48 MB/s
# [MK_04757.jpg] copied. Size 15.83 MB. Speed 4.43 MB/s
# [MK_04759.jpg] copied. Size 16.42 MB. Speed 4.38 MB/s
# [MK_04761.jpg] copied. Size 15.75 MB. Speed 5.06 MB/s
# [MK_04763.jpg] copied. Size 15.68 MB. Speed 5.85 MB/s
# [MK_04765.jpg] copied. Size 16.82 MB. Speed 7.20 MB/s
# [MK_04767.jpg] copied. Size 18.50 MB. Speed 5.61 MB/s
# [MK_04769.jpg] copied. Size 16.39 MB. Speed 6.29 MB/s
# [MK_04771.jpg] copied. Size 18.20 MB. Speed 7.49 MB/s
# [MK_04773.jpg] copied. Size 18.14 MB. Speed 6.33 MB/s
# [MK_04775.jpg] copied. Size 17.31 MB. Speed 7.15 MB/s
# [MK_04777.jpg] copied. Size 18.22 MB. Speed 6.23 MB/s
# [MK_04779.jpg] copied. Size 18.06 MB. Speed 6.80 MB/s
# [MK_04781.jpg] copied. Size 17.84 MB. Speed 6.27 MB/s
# [MK_04783.jpg] copied. Size 17.89 MB. Speed 7.13 MB/s
# [MK_04785.jpg] copied. Size 18.19 MB. Speed 6.94 MB/s
# [MK_04787.jpg] copied. Size 17.77 MB. Speed 6.94 MB/s
# [MK_04789.jpg] copied. Size 18.54 MB. Speed 5.73 MB/s
# [MK_04791.jpg] copied. Size 18.16 MB. Speed 6.73 MB/s
# [MK_04793.jpg] copied. Size 17.93 MB. Speed 7.08 MB/s
# [MK_04795.jpg] copied. Size 16.64 MB. Speed 5.95 MB/s
# [MK_04797.jpg] copied. Size 16.95 MB. Speed 3.78 MB/s
# [MK_04799.jpg] copied. Size 16.92 MB. Speed 6.40 MB/s
# [MK_04801.jpg] copied. Size 17.41 MB. Speed 6.28 MB/s
# [MK_04803.jpg] copied. Size 18.29 MB. Speed 7.07 MB/s
# [MK_04805.jpg] copied. Size 18.11 MB. Speed 5.41 MB/s
# [MK_04807.jpg] copied. Size 18.93 MB. Speed 7.18 MB/s
# [MK_04809.jpg] copied. Size 18.66 MB. Speed 4.83 MB/s
# [MK_04811.jpg] copied. Size 18.23 MB. Speed 4.45 MB/s
# [MK_04813.jpg] copied. Size 18.12 MB. Speed 5.77 MB/s
# [MK_04815.jpg] copied. Size 18.05 MB. Speed 4.87 MB/s
# [MK_04817.jpg] copied. Size 16.98 MB. Speed 6.98 MB/s
# [MK_04819.jpg] copied. Size 17.74 MB. Speed 5.20 MB/s
# [MK_04821.jpg] copied. Size 17.91 MB. Speed 6.57 MB/s
# [MK_04823.jpg] copied. Size 17.68 MB. Speed 7.29 MB/s
# [MK_04825.jpg] copied. Size 17.83 MB. Speed 5.67 MB/s
# [MK_04827.jpg] copied. Size 17.78 MB. Speed 6.89 MB/s
# [MK_04829.jpg] copied. Size 17.88 MB. Speed 5.84 MB/s
# [MK_04831.jpg] copied. Size 18.24 MB. Speed 5.51 MB/s
# [MK_04833.jpg] copied. Size 18.22 MB. Speed 7.26 MB/s
# [MK_04835.jpg] copied. Size 16.97 MB. Speed 5.22 MB/s
